# %% [markdown]
# # Project 1 Using Python, Pandas and Matplotlib
# ## change in alc cons vs shutdown length
# ## Group 3: Phil, Rob, Diane, Gurupdesh

# %%
import os
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
datafile = "Data/NIHmergedwithCOVIDdata.csv"

base_df = pd.read_csv(datafile)

base_df
# Out:
#       Unnamed: 0  Year  Month          State Beverage Type   Gallons  Ethanol  \
# 0              0  2017      1         Alaska       Spirits    103645    42598
# 1              1  2017      1       Arkansas       Spirits    402885   165586
# 2              2  2017      1       Colorado       Spirits    733857   301615
# 3              3  2017      1    Connecticut       Spirits    412100   169373
# 4              4  2017      1        Florida       Spirits   2770686  1138752
# ...          ...   ...    ...            ...           ...       ...      ...
# 1833        1833  2020      6  Massachusetts          Beer  10335283   465088
# 1834        1834  2020      6       Missouri          Beer  11099851   499493
# 1835        1835  2020      6   North Dakota          Beer   2091390    94113
# 1836        1836  2020      6         Oregon          Beer   7969948   358648
# 1837        1837  2020      6          Texas          Beer  62290399  2803068
#
#       Population  PerCapita  PerCapita3yr  PctChange  index  positive  \
# 0         593378     0.0718           NaN        NaN    NaN       NaN
# 1        2455022     0.0674           NaN        NaN    NaN       NaN
# 2        4634346     0.0651           NaN        NaN    NaN       NaN
# 3        3015481     0.0562           NaN        NaN    NaN       NaN
# 4       17722275     0.0643           NaN        NaN    NaN       NaN
# ...          ...        ...           ...        ...    ...       ...
# 1833     5862386     0.0793        0.0913    -0.1312  190.0  108882.0
# 1834     5077875     0.0984        0.1056    -0.0682  222.0   21551.0
# 1835      617880     0.1523        0.1664    -0.0844  295.0    3574.0
# 1836     3547474     0.1011        0.1135    -0.1092  327.0    8656.0
# 1837    23257363     0.1205        0.1216    -0.0085  383.0  159986.0
#
#       totalTestResults  Positivity Rate  Shutdown Length
# 0                  NaN             0.00                0
# 1                  NaN             0.00                0
# 2                  NaN             0.00               31
# 3                  NaN             0.00                0
# 4                  NaN             0.00               31
# ...                ...              ...              ...
# 1833         1103550.0             9.87               55
# 1834          424214.0             5.08               27
# 1835          178468.0             2.00                0
# 1836          237634.0             3.64                0
# 1837         1869282.0             8.56               28
#
# [1838 rows x 16 columns]

# %%
monthlist = [3,4,5,6]
monthrelevant_df = base_df.loc[base_df['Month'].map(lambda x: x in monthlist),:].reset_index()


monthrelevant_df
# Out:
#      level_0  Unnamed: 0  Year  Month          State Beverage Type   Gallons  \
# 0         88          88  2017      3         Alaska       Spirits    141033
# 1         89          89  2017      3       Arkansas       Spirits    289006
# 2         90          90  2017      3       Colorado       Spirits   1154429
# 3         91          91  2017      3    Connecticut       Spirits    581433
# 4         92          92  2017      3        Florida       Spirits   4217222
# ..       ...         ...   ...    ...            ...           ...       ...
# 689     1833        1833  2020      6  Massachusetts          Beer  10335283
# 690     1834        1834  2020      6       Missouri          Beer  11099851
# 691     1835        1835  2020      6   North Dakota          Beer   2091390
# 692     1836        1836  2020      6         Oregon          Beer   7969948
# 693     1837        1837  2020      6          Texas          Beer  62290399
#
#      Ethanol  Population  PerCapita  PerCapita3yr  PctChange  index  positive  \
# 0      57964      593378     0.0977           NaN        NaN    NaN       NaN
# 1     118781     2455022     0.0484           NaN        NaN    NaN       NaN
# 2     474470     4634346     0.1024           NaN        NaN    NaN       NaN
# 3     238969     3015481     0.0792           NaN        NaN    NaN       NaN
# 4    1733278    17722275     0.0978           NaN        NaN    NaN       NaN
# ..       ...         ...        ...           ...        ...    ...       ...
# 689   465088     5862386     0.0793        0.0913    -0.1312  190.0  108882.0
# 690   499493     5077875     0.0984        0.1056    -0.0682  222.0   21551.0
# 691    94113      617880     0.1523        0.1664    -0.0844  295.0    3574.0
# 692   358648     3547474     0.1011        0.1135    -0.1092  327.0    8656.0
# 693  2803068    23257363     0.1205        0.1216    -0.0085  383.0  159986.0
#
#      totalTestResults  Positivity Rate  Shutdown Length
# 0                 NaN             0.00                0
# 1                 NaN             0.00                0
# 2                 NaN             0.00               31
# 3                 NaN             0.00                0
# 4                 NaN             0.00               31
# ..                ...              ...              ...
# 689         1103550.0             9.87               55
# 690          424214.0             5.08               27
# 691          178468.0             2.00                0
# 692          237634.0             3.64                0
# 693         1869282.0             8.56               28
#
# [694 rows x 17 columns]

# %%
year_groupby = monthrelevant_df.groupby(['Year','State'])

ethanol2 = year_groupby['Ethanol'].sum()
population2 = year_groupby['Population'].max()
shutdown2 = year_groupby['Shutdown Length'].max()
percapita2 = ethanol2/population2

grouped_df = pd.DataFrame({"Ethanol": ethanol2,
                                          "Population": population2,
                                          "Shutdown Length": shutdown2,
                                          "Per Capita Consumption": percapita2})

grouped_df = grouped_df.reset_index()

grouped_df
# Out:
#     Year         State   Ethanol  Population  Shutdown Length  \
# 0   2017        Alaska    598164      593378                0
# 1   2017      Arkansas   1449680     2455022                0
# 2   2017      Colorado   4616704     4634346               31
# 3   2017   Connecticut   2555639     3015481                0
# 4   2017       Florida  16531938    17722275               31
# ..   ...           ...       ...         ...              ...
# 59  2020  North Dakota    699408      617880                0
# 60  2020        Oregon   1876993     3547474                0
# 61  2020         Texas  18233596    23257363               28
# 62  2020      Virginia   4851935     7094962                0
# 63  2020     Wisconsin   2541483     4851640               49
#
#     Per Capita Consumption
# 0                 1.008066
# 1                 0.590496
# 2                 0.996193
# 3                 0.847506
# 4                 0.932834
# ..                     ...
# 59                1.131948
# 60                0.529107
# 61                0.783992
# 62                0.683856
# 63                0.523840
#
# [64 rows x 6 columns]

# %%
After_df = grouped_df.loc[grouped_df['Year'] == 2020,:].reset_index()
Before_df = grouped_df.loc[(grouped_df['Year'] == 2017)|(grouped_df['Year'] == 2018)|(grouped_df['Year'] == 2019),:].reset_index()

After_df['Per Capita After'] = After_df['Per Capita Consumption']
After_df = After_df[['State','Per Capita After','Shutdown Length']]

After_df
# Out:
#             State  Per Capita After  Shutdown Length
# 0          Alaska          0.986497                0
# 1        Arkansas          0.623286                0
# 2        Colorado          0.740326               31
# 3     Connecticut          0.370593                0
# 4         Florida          0.926596               31
# 5        Illinois          0.808750               70
# 6          Kansas          0.631155               35
# 7        Kentucky          0.690946                0
# 8       Louisiana          0.470263               46
# 9   Massachusetts          0.911014               55
# 10       Missouri          0.920897               27
# 11   North Dakota          1.131948                0
# 12         Oregon          0.529107                0
# 13          Texas          0.783992               28
# 14       Virginia          0.683856                0
# 15      Wisconsin          0.523840               49

# %%
before_groupby = Before_df.groupby(['State'])

ethanol3 = before_groupby['Ethanol'].sum()
population3 = before_groupby['Population'].sum()
percapita3 = ethanol3/population3

combinedBefore_df = pd.DataFrame({"Ethanol": ethanol3,
                                          "Population": population3,
                                          "Per Capita Before": percapita3})

combinedBefore_df = combinedBefore_df.reset_index()

combinedBefore_df
# Out:
#             State   Ethanol  Population  Per Capita Before
# 0          Alaska   1790553     1773619           1.009548
# 1        Arkansas   4474961     7396406           0.605018
# 2        Colorado  13711576    14139532           0.969733
# 3     Connecticut   7517876     9053819           0.830354
# 4         Florida  49909936    53910584           0.925791
# 5        Illinois  26615836    31601950           0.842221
# 6          Kansas   4229893     7091946           0.596436
# 7        Kentucky   7261012    11043383           0.657499
# 8       Louisiana   5139712    11410187           0.450449
# 9   Massachusetts  16531138    17522338           0.943432
# 10       Missouri  13764846    15172259           0.907238
# 11   North Dakota   2094402     1846208           1.134434
# 12         Oregon   6068869    10525047           0.576612
# 13          Texas  51457464    68729609           0.748694
# 14       Virginia  15373538    21166630           0.726310
# 15      Wisconsin   7736894    14486325           0.534083

# %%
final_df = pd.merge(combinedBefore_df, After_df, how='inner')
final_df = final_df[['State','Per Capita Before','Per Capita After','Shutdown Length']]
final_df["Change In Consumption Rate"] = final_df["Per Capita After"]/final_df["Per Capita Before"]
final_df
# Out:
#             State  Per Capita Before  Per Capita After  Shutdown Length  \
# 0          Alaska           1.009548          0.986497                0
# 1        Arkansas           0.605018          0.623286                0
# 2        Colorado           0.969733          0.740326               31
# 3     Connecticut           0.830354          0.370593                0
# 4         Florida           0.925791          0.926596               31
# 5        Illinois           0.842221          0.808750               70
# 6          Kansas           0.596436          0.631155               35
# 7        Kentucky           0.657499          0.690946                0
# 8       Louisiana           0.450449          0.470263               46
# 9   Massachusetts           0.943432          0.911014               55
# 10       Missouri           0.907238          0.920897               27
# 11   North Dakota           1.134434          1.131948                0
# 12         Oregon           0.576612          0.529107                0
# 13          Texas           0.748694          0.783992               28
# 14       Virginia           0.726310          0.683856                0
# 15      Wisconsin           0.534083          0.523840               49
#
#     Change In Consumption Rate
# 0                     0.977167
# 1                     1.030194
# 2                     0.763433
# 3                     0.446307
# 4                     1.000869
# 5                     0.960258
# 6                     1.058211
# 7                     1.050871
# 8                     1.043986
# 9                     0.965638
# 10                    1.015056
# 11                    0.997808
# 12                    0.917613
# 13                    1.047146
# 14                    0.941549
# 15                    0.980822

# %%
final_df.plot.scatter(x='Shutdown Length', y='Change In Consumption Rate')

# %%
# gonna try to make a lr
